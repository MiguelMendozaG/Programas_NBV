# %%
#crea un octree de 32x32x32 del archivo de entrada indicado
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,  AutoMinorLocator)

# %%
majorLocator = MultipleLocator(1)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(5)

# %%
f11_r3d = np.array([36.46,68.07,74.76,94.58,94.79,94.97,95.61])
f11_vn = np.array([36.46,73.71,90.96,92.07])
f11_std = np.array([])
print(len(f11_r3d))
# Out:
# 7

# %%
fig = plt.figure()
fig, ax = plt.subplots()
x_r3d = np.arange(0, len(f11_r3d),1)
x_vn = np.arange(0, len(f11_vn),1)
#ax.set_title("Figure 1")
ax.set_xlabel('Iteration')
ax.set_ylabel('% of covered surface')
ax.plot(x_r3d, f11_r3d, 'b--', label = 'NBV-Net')
ax.plot(x_vn, f11_vn, 'r', label = 'VoxNet')
ax.errorbar()
ax.legend()
#fig.show()
#fig.savefig("cov_surf_f1.eps", dpi = 300)

# %%
f13_r3d = np.array([40.41,72.40,73.94,77.3,78.63,81.76,81.87,81.87])
f13_vn = np.array([40.41,72.4,78.33,79.56])
print(len(f11_r3d))
fig = plt.figure()
fig, ax = plt.subplots()
x_r3d = np.arange(0, len(f13_r3d),1)
x_vn = np.arange(0, len(f13_vn),1)
#ax.set_title("Figure 2")
ax.set_xlabel('Iteration')
ax.set_ylabel('% of covered surface')
ax.plot(x_r3d, f13_r3d, 'b--', label = 'NBV-Net')
ax.plot(x_vn, f13_vn, 'r', label = 'VoxNet')
ax.legend()
fig.show()
fig.savefig("cov_surf_f2.eps", dpi = 300)
# Out:
# 7
# /home/miguelmg/anaconda3/envs/tensorflow/lib/python3.5/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f15_r3d = np.array([43.01,64.94,70.83,86,86.71,86.95,87.12,88.19])
f15_vn = np.array([43.01,69.67,85.25,85.56])
fig = plt.figure()
fig, ax = plt.subplots()
x_r3d = np.arange(0, len(f15_r3d),1)
x_vn = np.arange(0, len(f15_vn),1)
#ax.set_title("Figure 3")
ax.set_xlabel('Iteration')
ax.set_ylabel('% of covered surface')
ax.plot(x_r3d, f15_r3d, 'b--', label = 'NBV-Net')
ax.plot(x_vn, f15_vn, 'r', label = 'VoxNet')
ax.legend()
fig.show()
fig.savefig("cov_surf_f3.eps", dpi = 300)
# Out:
# /home/miguelmg/anaconda3/envs/tensorflow/lib/python3.5/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig1_m_r3d = np.array([94.62, 95.61, 88.82, 84.69, 94.94,95.62,95.13,94,95.62,92.79])
fig1_m_vx = np.array([87.17,92.07,58.01,90.25,74.74,91.97,91.01,84.47,73.39,95.74])

fig2_m_r3d = np.array([80.65,77.63,81.87,81.61,82.78,81.23,81.6,80.97,79.07,81.35])
fig2_m_vx = np.array([74.71,76.98,79.56,79.5,77.11,76.01,79.79,77.45,79.74,75.53])

fig3_m_r3d = np.array([80.65,83.85,88.19,86.65,80.84,85.57,80.61,89.37,81.01,83.94])
fig3_m_vx = np.array([83.09,78.26,85.56,77.35,82,79.65,75.27,89.37,76.73,67.9])

fig1_m_r3d_mean = np.mean(fig1_m_r3d)
fig1_m_vx_mean = np.mean(fig1_m_vx)

fig2_m_r3d_mean = np.mean(fig2_m_r3d)
fig2_m_vx_mean = np.mean(fig2_m_vx)

fig3_m_r3d_mean = np.mean(fig3_m_r3d)
fig3_m_vx_mean = np.mean(fig3_m_vx)

mean_r3d = np.array([fig1_m_r3d_mean, fig2_m_r3d_mean, fig3_m_r3d_mean])
mean_vx = np.array([fig1_m_vx_mean, fig2_m_vx_mean, fig3_m_vx_mean])
x = np.arange(1,4)

print(mean_r3d, mean_vx)
# Out:
# [93.184 80.876 84.068] [83.882 77.638 79.518]

# %%
print(np.std(fig3_m_vx))
# Out:
# 5.6531739757414154

# %%
fig = plt.figure()
fig, ax = plt.subplots()

ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)

# for the minor ticks, use no labels; default NullFormatter
ax.xaxis.set_minor_locator(minorLocator)

ax.set_xlabel('Figures')
ax.set_ylabel('Mean of covered surface')
ax.plot(x, mean_r3d, 'b--', label = 'NBV-Net')
ax.plot(x, mean_vx, 'r', label = 'VoxNet')
ax.legend()
ax.set_ylim(bottom=50, top = 100)
fig.show()
fig.savefig("mean_covered_surface.jpg", dpi = 300)
# Out:
# /home/miguelmg/anaconda3/envs/tensorflow/lib/python3.5/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ## Datos de la figura 1 (botella)

# %% [markdown]
# ### NBV-Net

# %%
init_pose = np.array([55.248,36.462,51.77,50.64,54.35,52.33,47.43,51.25,53.59,51.62])
fig1_nbvnet_iter_1 = np.array([87.12,68.07,85.33,79.86,89.86,68.39,74.48,86.37,62.7,92.79])
fig1_nbvnet_iter_2 = np.array([92.64,74.76,85.67,84.47,94.06,93.1,77.14,86.58,91.65,92.79])
fig1_nbvnet_iter_3 = np.array([94.5,94.58,85.78,84.48,94.94,94.69,95.13,88.79,94.97,92.79])
fig1_nbvnet_iter_4 = np.array([94.62,94.79,88.82,84.69,94.94,94.81,95.13,94,95.07,92.79])
fig1_nbvnet_iter_5 = np.array([94.62,94.97,88.82,84.69,94.94,95.41,95.13,94,95.41,92.79])
fig1_nbvnet_iter_6 = np.array([94.62,95.61,88.82,84.69,94.94,95.62,95.13,94,95.62,92.79])
fig1_nbvnet_iter_7 = np.array([94.5,95.61,88.82,84.69,94.94,95.62,95.13,94,95.62,92.79])

# %% [markdown]
# ## desviacion estandar de cobertura

# %%
init_pose_std = np.std(init_pose)
fig1_nbvnet_iter_1_std = np.std(fig1_nbvnet_iter_1)
fig1_nbvnet_iter_2_std = np.std(fig1_nbvnet_iter_2)
fig1_nbvnet_iter_3_std = np.std(fig1_nbvnet_iter_3)
fig1_nbvnet_iter_4_std = np.std(fig1_nbvnet_iter_4)
fig1_nbvnet_iter_5_std = np.std(fig1_nbvnet_iter_5)
fig1_nbvnet_iter_6_std = np.std(fig1_nbvnet_iter_6)
fig1_nbvnet_iter_7_std = np.std(fig1_nbvnet_iter_7)
fig1_nbvnet_std = np.array([init_pose_std,fig1_nbvnet_iter_1_std, fig1_nbvnet_iter_2_std, fig1_nbvnet_iter_3_std, fig1_nbvnet_iter_4_std, fig1_nbvnet_iter_5_std, fig1_nbvnet_iter_6_std, fig1_nbvnet_iter_7_std])
print(fig1_nbvnet_std)
# Out:
# [ 5.10091304  9.92396498  6.54656582  3.91827322  3.30531451  3.37540753
#   3.44528431  3.44046741]

# %%
init_pose_mean = np.mean(init_pose)
fig1_nbv_1 = np.mean(fig1_nbvnet_iter_1)
fig1_nbv_2 = np.mean(fig1_nbvnet_iter_2)
fig1_nbv_3 = np.mean(fig1_nbvnet_iter_3)
fig1_nbv_4 = np.mean(fig1_nbvnet_iter_4)
fig1_nbv_5 = np.mean(fig1_nbvnet_iter_5)
fig1_nbv_6 = np.mean(fig1_nbvnet_iter_6)
fig1_nbv_7 = np.mean(fig1_nbvnet_iter_7)
print(init_pose_mean)
print(fig1_nbv_1, fig1_nbv_2, fig1_nbv_3, fig1_nbv_4, fig1_nbv_5, fig1_nbv_6, fig1_nbv_7)
print(len(fig1_nbvnet_iter_1), len(fig1_nbvnet_iter_2), len(fig1_nbvnet_iter_3), len(fig1_nbvnet_iter_4), len(fig1_nbvnet_iter_5), len(fig1_nbvnet_iter_6), len(fig1_nbvnet_iter_7))
# Out:
# 50.469
# (79.497, 87.285999999999987, 92.064999999999998, 92.96599999999998, 93.078000000000003, 93.183999999999997, 93.171999999999997)
# (10, 10, 10, 10, 10, 10, 10)

# %%
print(np.std(fig1_nbvnet_iter_7))
# Out:
# 3.44046741011

# %% [markdown]
# ### VoxNet

# %%
fig1_vx_iter_1 = np.array([67.5,36.46,55.22,69.86,74.74,68.39,75.46,55.46,59.83,95.65])
fig1_vx_iter_2 = np.array([87.17,73.71,58.01,90.25,74.74,91.97,91.01,58.01,73.39,95.74])
fig1_vx_iter_3 = np.array([87.17,90.96,58.01,90.25,74.74,91.97,91.01,84.47,73.39,95.74])
fig1_vx_1 = np.mean(fig1_vx_iter_1)
fig1_vx_2 = np.mean(fig1_vx_iter_2)
fig1_vx_3 = np.mean(fig1_vx_iter_3)

print(fig1_vx_1, fig1_vx_2, fig1_vx_3)
print(len(fig1_vx_iter_1), len(fig1_vx_iter_2), len(fig1_vx_iter_3))
# Out:
# (65.856999999999999, 79.400000000000006, 83.770999999999987)
# (10, 10, 10)

# %% [markdown]
# ## Desviacion estandar cobertura

# %%
fig1_vx_iter_1_std = np.std(fig1_vx_iter_1)
fig1_vx_iter_2_std = np.std(fig1_vx_iter_2)
fig1_vx_iter_3_std = np.std(fig1_vx_iter_3)
fig1_vx_std = np.array([init_pose_std,fig1_vx_iter_1_std,fig1_vx_iter_2_std,fig1_vx_iter_3_std])
print(fig1_vx_std)
# Out:
# [  5.10091304  14.85139525  13.20289362  11.05232053]

# %%
print(np.std(fig1_vx_iter_3))
# Out:
# 11.0523205256

# %% [markdown]
# #### Grafica

# %%
v1_1 = np.array([init_pose_mean,fig1_vx_1, fig1_vx_2, fig1_vx_3])
v2_1 = np.array([init_pose_mean,fig1_nbv_1, fig1_nbv_2, fig1_nbv_3, fig1_nbv_4,  fig1_nbv_5, fig1_nbv_6, fig1_nbv_7])
v1_1_len = np.arange(0, len(v1_1),1)
v2_1_len = np.arange(0, len(v2_1), 1)
fig = plt.figure()
fig, ax = plt.subplots()
#ax.set_title("Figure 3")
ax.set_xlabel(u'Iteration')
ax.set_ylabel('% of covered surface')
ax.plot(v2_1_len, v2_1,'b--', label = 'NBV-Net')
ax.plot(v1_1_len, v1_1, 'r', label = 'VoxNet')

ax.errorbar(v2_1_len, v2_1, fig1_nbvnet_std, color = 'blue', ls = '--')
ax.errorbar(v1_1_len, v1_1,fig1_vx_std, color = 'red')
ax.legend(loc = 'bottom right')
fig.show()
fig.savefig("cov_surf_f1_mean.eps", dpi = 300)
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/legend.py:325: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	right
# 	center left
# 	upper right
# 	lower right
# 	best
# 	center
# 	lower left
# 	center right
# 	upper left
# 	upper center
# 	lower center
#
#   six.iterkeys(self.codes))))
# /usr/lib/python2.7/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ## Datos de la figura 2 (plancha)

# %% [markdown]
# ### NBV_Net

# %%
init_pose_2 = np.array([41.52,46.85,40.45,49.39,38.38,43.69,22.24,37.68,41.07,42.78])
fig2_nbvnet_iter_1 = np.array([72.42,76.83,72.4,70.91,65.78,73.02,52.28,68.98,70.86,69.99])
fig2_nbvnet_iter_2 = np.array([77.11,77.63,73.94,75.09,76.88,73.02,80.8,78.77,79.04,74.4])
fig2_nbvnet_iter_3 = np.array([77.77,77.63,77.3,79.71,79.75,81.03,80.81,79.1,79.07,77.45,])
fig2_nbvnet_iter_4 = np.array([80.65,77.63,78.62,81.32,80.61,81.23,81.6,80.2,79.07,81.35])
fig2_nbvnet_iter_5 = np.array([80.65,77.63,81.76,81.61,80.73,81.23,81.6,80.97,79.09,81.35])
fig2_nbvnet_iter_6 = np.array([80.65,77.63,81.87,81.61,82.78,81.23,81.6,80.97,79.07,81.35])
fig2_nbvnet_iter_7 = np.array([80.65,77.63,81.87,81.61,82.78,81.23,81.6,80.97,79.07,81.35])

init_pose_mean_2 = np.mean(init_pose_2)
fig2_nbvnet_1 = np.mean(fig2_nbvnet_iter_1)
fig2_nbvnet_2 = np.mean(fig2_nbvnet_iter_2)
fig2_nbvnet_3 = np.mean(fig2_nbvnet_iter_3)
fig2_nbvnet_4 = np.mean(fig2_nbvnet_iter_4)
fig2_nbvnet_5 = np.mean(fig2_nbvnet_iter_5)
fig2_nbvnet_6 = np.mean(fig2_nbvnet_iter_6)
fig2_nbvnet_7 = np.mean(fig2_nbvnet_iter_7)
print(init_pose_mean_2)
print(fig2_nbvnet_1, 
      fig2_nbvnet_2, 
      fig2_nbvnet_3, 
      fig2_nbvnet_4, 
      fig2_nbvnet_5, 
      fig2_nbvnet_6, 
      fig2_nbvnet_7)
print(len(fig2_nbvnet_iter_1), 
      len(fig2_nbvnet_iter_2), 
      len(fig2_nbvnet_iter_3), 
      len(fig2_nbvnet_iter_4), 
      len(fig2_nbvnet_iter_5), 
      len(fig2_nbvnet_iter_6), 
      len(fig2_nbvnet_iter_7))
# Out:
# 40.405
# (69.347000000000008, 76.667999999999992, 78.961999999999989, 80.228000000000009, 80.662000000000006, 80.875999999999991, 80.875999999999991)
# (10, 10, 10, 10, 10, 10, 10)

# %% [markdown]
# ## Desviacion estandar cobertura

# %%
init_pose_2_std = np.std(init_pose_2)
fig2_nbvnet_iter_1_std = np.std(fig2_nbvnet_iter_1)
fig2_nbvnet_iter_2_std = np.std(fig2_nbvnet_iter_2)
fig2_nbvnet_iter_3_std = np.std(fig2_nbvnet_iter_3)
fig2_nbvnet_iter_4_std = np.std(fig2_nbvnet_iter_4)
fig2_nbvnet_iter_5_std = np.std(fig2_nbvnet_iter_5)
fig2_nbvnet_iter_6_std = np.std(fig2_nbvnet_iter_6)
fig2_nbvnet_iter_7_std = np.std(fig2_nbvnet_iter_7)
fig2_nbvnet_std = np.array([init_pose_2_std, fig2_nbvnet_iter_1_std, fig2_nbvnet_iter_2_std, fig2_nbvnet_iter_3_std, fig2_nbvnet_iter_4_std, fig2_nbvnet_iter_5_std, fig2_nbvnet_iter_6_std, fig2_nbvnet_iter_7_std])
print(fig2_nbvnet_std)
# Out:
# [ 6.94176527  6.30505044  2.38049911  1.3094411   1.27823159  1.24675419
#   1.41011489  1.41011489]

# %%
print(np.std(fig2_nbvnet_iter_7))
# Out:
# 1.41011488894

# %% [markdown]
# ### VoxNet

# %%
fig2_vx_iter_1 = np.array([68.8,71.84,78.33,60.25,67.64,47.96,55.25,68.98,54.36,52.86])
fig2_vx_iter_2 = np.array([74.71,76.98,79.56,76.69,77.11,57.89,77.99,77.45,78.99,75.53])
fig2_vx_iter_3 = np.array([74.71,76.98,79.56,77.32,77.11,76.01,79.79,77.45,79.74,75.53])
fig2_vx_iter_4 = np.array([74.71,76.98,79.56,79.50,77.11,76.01,79.79,77.45,79.74,75.53])

fig2_vx_1 = np.mean(fig2_vx_iter_1)
fig2_vx_2 = np.mean(fig2_vx_iter_2)
fig2_vx_3 = np.mean(fig2_vx_iter_3)
fig2_vx_4 = np.mean(fig2_vx_iter_4)

print(fig2_vx_1, 
      fig2_vx_2, 
      fig2_vx_3, 
      fig2_vx_4)
print(len(fig2_vx_iter_1), 
      len(fig2_vx_iter_2), 
      len(fig2_vx_iter_3), 
      len(fig2_vx_iter_4))
# Out:
# (62.626999999999995, 75.289999999999992, 77.420000000000002, 77.638000000000005)
# (10, 10, 10, 10)

# %% [markdown]
# ## desviacion estandar cobertura

# %%
fig2_voxnet_iter_1_std = np.std(fig2_vx_iter_1)
fig2_voxnet_iter_2_std = np.std(fig2_vx_iter_2)
fig2_voxnet_iter_3_std = np.std(fig2_vx_iter_3)
fig2_voxnet_iter_4_std = np.std(fig2_vx_iter_4)
fig2_vx_std = np.array([init_pose_2_std, fig2_voxnet_iter_1_std, fig2_voxnet_iter_2_std, fig2_voxnet_iter_3_std])
print(fig2_vx_std)
# Out:
# [ 6.94176527  9.34873794  5.95953857  1.69657891]

# %%
print(np.std(fig2_vx_iter_4))
# Out:
# 1.80623807955

# %% [markdown]
# #### Grafica

# %%
v1_2 = np.array([init_pose_mean_2,fig2_vx_1, fig2_vx_2, fig2_vx_3])
v2_2 = np.array([init_pose_mean_2,fig2_nbvnet_1, fig2_nbvnet_2, fig2_nbvnet_3, fig2_nbvnet_4, fig2_nbvnet_5, fig2_nbvnet_6, fig2_nbvnet_7])
v1_2_len = np.arange(0, len(v1_2),1)
v2_2_len = np.arange(0, len(v2_2), 1)
fig = plt.figure()
fig, ax = plt.subplots()
#ax.set_title("Figure 3")
ax.set_xlabel(u'Iteration')
ax.set_ylabel('% of covered surface')
ax.plot(v2_2_len, v2_2,'b--', label = 'NBV-Net')
ax.plot(v1_2_len, v1_2, 'r', label = 'VoxNet')

ax.errorbar(v2_2_len, v2_2, fig2_nbvnet_std, color = 'blue', ls = '--')
ax.errorbar(v1_2_len, v1_2, fig2_vx_std, color = 'red')

ax.legend(loc = 'bottom right')
fig.show()
fig.savefig("iron_eng.eps", dpi = 300)

# %% [markdown]
# ## Datos de la figura 3 (telefono)

# %% [markdown]
# ### NBV-Net

# %%
init_pose_3 = np.array([40.40,39.40,43.01,45.6,46.87,44.14,43.22,45.58,44,40.25])
fig3_nbvnet_iter_1 = np.array([77.67,68.51,64.94,64.79,55.52,54.49,65.21,82.76,76.73,67.9])
fig3_nbvnet_iter_2 = np.array([83.09,78.26,85.56,69.06,60.42,61.25,80.61,88.58,81.01,78.96])
fig3_nbvnet_iter_3 = np.array([83.09,83.85,86,86.65,72.28,85.57,80.61,89.37,81.01,83.94])
fig3_nbvnet_iter_4 = np.array([83.09,83.85,86.71,86.65,73.57,85.57,80.61,89.37,81.01,83.94])
fig3_nbvnet_iter_5 = np.array([83.09,83.85,86.95,86.65,73.57,85.57,80.61,89.37,81.01,83.94])
fig3_nbvnet_iter_6 = np.array([83.09,83.85,87.12,86.65,80.84,85.57,80.61,89.37,81.01,83.94])
fig3_nbvnet_iter_7 = np.array([83.09,83.85,88.19,86.65,80.84,85.57,80.61,89.37,81.01,83.94])

init_pose_mean_3 = np.mean(init_pose_3)
fig3_nbvnet_1 = np.mean(fig3_nbvnet_iter_1)
fig3_nbvnet_2 = np.mean(fig3_nbvnet_iter_2)
fig3_nbvnet_3 = np.mean(fig3_nbvnet_iter_3)
fig3_nbvnet_4 = np.mean(fig3_nbvnet_iter_4)
fig3_nbvnet_5 = np.mean(fig3_nbvnet_iter_5)
fig3_nbvnet_6 = np.mean(fig3_nbvnet_iter_6)
fig3_nbvnet_7 = np.mean(fig3_nbvnet_iter_7)
print(init_pose_mean_3)
print(fig3_nbvnet_1, 
      fig3_nbvnet_2, 
      fig3_nbvnet_3, 
      fig3_nbvnet_4, 
      fig3_nbvnet_5, 
      fig3_nbvnet_6, 
      fig3_nbvnet_7)
print(len(fig3_nbvnet_iter_1), 
      len(fig3_nbvnet_iter_2), 
      len(fig3_nbvnet_iter_3), 
      len(fig3_nbvnet_iter_4), 
      len(fig3_nbvnet_iter_5), 
      len(fig3_nbvnet_iter_6), 
      len(fig3_nbvnet_iter_7))
# Out:
# 43.247
# (67.852000000000004, 76.680000000000007, 83.237000000000009, 83.437000000000012, 83.461000000000013, 84.204999999999998, 84.311999999999983)
# (10, 10, 10, 10, 10, 10, 10)

# %% [markdown]
# ## Desviacion estandar cobertura

# %%
init_std_fig3 = np.std(init_pose_3)
fig3_nbvnet_iter1_std = np.std(fig3_nbvnet_iter_1)
fig3_nbvnet_iter2_std = np.std(fig3_nbvnet_iter_2)
fig3_nbvnet_iter3_std = np.std(fig3_nbvnet_iter_3)
fig3_nbvnet_iter4_std = np.std(fig3_nbvnet_iter_4)
fig3_nbvnet_iter5_std = np.std(fig3_nbvnet_iter_5)
fig3_nbvnet_iter6_std = np.std(fig3_nbvnet_iter_6)
fig3_nbvnet_iter7_std = np.std(fig3_nbvnet_iter_7)
fig3_nbvnet_std = np.array([init_std_fig3, fig3_nbvnet_iter1_std, fig3_nbvnet_iter2_std, fig3_nbvnet_iter3_std, fig3_nbvnet_iter4_std, fig3_nbvnet_iter5_std, fig3_nbvnet_iter6_std, fig3_nbvnet_iter7_std])
print(fig3_nbvnet_std)
# Out:
# [ 2.3961179   8.67958962  9.29504169  4.41754921  4.15415467  4.17364217
#   2.80910039  2.93562532]

# %% [markdown]
# ### VoxNet

# %%
fig3_vx_iter_1 = np.array([77.67,78.26,69.67,77.35,80.91,77.28,64.09,78.66,76.73,67.9])
fig3_vx_iter_2 = np.array([80.65,78.26,85.56,77.35,82,79.65,75.27,85.31,76.73,67.90])
fig3_vx_iter_3 = np.array([80.65,78.26,85.56,77.35,82,79.65,75.27,89.37,76.73,67.9])

fig3_vx_1 = np.mean(fig3_vx_iter_1)
fig3_vx_2 = np.mean(fig3_vx_iter_2)
fig3_vx_3 = np.mean(fig3_vx_iter_3)

print(fig3_vx_1, 
      fig3_vx_2, 
      fig3_vx_3)
print(len(fig3_vx_iter_1), 
      len(fig3_vx_iter_2), 
      len(fig3_vx_iter_3))
# Out:
# (74.852000000000004, 78.868000000000009, 79.274000000000001)
# (10, 10, 10)

# %% [markdown]
# ## Desviacion estandar cobertura

# %%
fig3_vx_iter1_std = np.std(fig3_vx_iter_1)
fig3_vx_iter2_std = np.std(fig3_vx_iter_2)
fig3_vx_iter3_std = np.std(fig3_vx_iter_3)
fig3_vx_std = np.array([init_std_fig3, fig3_vx_iter1_std, fig3_vx_iter2_std, fig3_vx_iter3_std])
print(fig3_vx_std)
# Out:
# [ 2.3961179   5.2670861   4.90271721  5.54536419]

# %%
v1_3 = np.array([init_pose_mean_3,fig3_vx_1, fig3_vx_2, fig3_vx_3])
v2_3 = np.array([init_pose_mean_3,fig3_nbvnet_1, fig3_nbvnet_2, fig3_nbvnet_3, fig3_nbvnet_4, fig3_nbvnet_5, fig3_nbvnet_6, fig3_nbvnet_7])
v1_3_len = np.arange(0, len(v1_3),1)
v2_3_len = np.arange(0, len(v2_3), 1)
fig = plt.figure()
fig, ax = plt.subplots()
#ax.set_title("Figure 3")
ax.set_xlabel(u'Iteration')
ax.set_ylabel('% of covered surface')
ax.plot(v2_3_len, v2_3,'b--', label = 'NBV-Net')
ax.plot(v1_3_len, v1_3, 'r', label = 'VoxNet')

ax.errorbar(v2_3_len, v2_3, fig3_nbvnet_std,color = 'blue', ls = '--')
ax.errorbar(v1_3_len, v1_3, fig3_vx_std,color = 'red')

ax.legend(loc = 'bottom right')
fig.show()
fig.savefig("telephone_eng.eps", dpi = 300)

# %%
a = 49.4154 + 58.7365 + 62.9744 + 66.7683 + 69.4077 + 71.4218 + 71.7936 + 72.1062 
a
# Out:
# 522.6239

# %%
# Out:
# 2.8658627988354657
